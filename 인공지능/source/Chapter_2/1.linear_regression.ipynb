# %%
from tensorflow.keras.models import Sequential # 케라스의 Sequential()을 임포트
from tensorflow.keras.layers import Dense      # 케라스의 Dense()를 임포트
from tensorflow.keras import optimizers        # 케라스의 옵티마이저를 임포트
import numpy as np # Numpy를 임포트
import matplotlib.pyplot as plt

X=np.array([1,2,3,4,5]) 
Y=np.array([1,2,3,4,5]) 

model=Sequential()
model.add(Dense(1, input_dim=1, activation='linear'))
sgd=optimizers.SGD(lr=0.01)
model.compile(optimizer=sgd ,loss='mse',metrics=['accuracy'])
model.fit(X,Y, batch_size=1, epochs=100, shuffle=False)

print(model.predict(X))
plt.plot(X, Y, 'bo')
plt.plot(X, model.predict(X), 'r-')
plt.show()
# Out:
# Epoch 1/100
# C:\Users\jikim\anaconda3\lib\site-packages\keras\optimizer_v2\gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 5/5 [==============================] - 1s 2ms/step - loss: 0.4879 - accuracy: 0.2000
# Epoch 2/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0236 - accuracy: 0.2000
# Epoch 3/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0021 - accuracy: 0.2000
# Epoch 4/100
# 5/5 [==============================] - 0s 6ms/step - loss: 0.0013 - accuracy: 0.2000
# Epoch 5/100
# 5/5 [==============================] - 0s 5ms/step - loss: 0.0013 - accuracy: 0.2000
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0013 - accuracy: 0.2000
# Epoch 7/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.2000
# Epoch 8/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0012 - accuracy: 0.2000
# Epoch 9/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0012 - accuracy: 0.2000
# Epoch 10/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0011 - accuracy: 0.2000
# Epoch 11/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0011 - accuracy: 0.2000
# Epoch 12/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0010 - accuracy: 0.2000
# Epoch 13/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.0010 - accuracy: 0.2000
# Epoch 14/100
# 5/5 [==============================] - 0s 2ms/step - loss: 9.6961e-04 - accuracy: 0.2000
# Epoch 15/100
# 5/5 [==============================] - 0s 1ms/step - loss: 9.3524e-04 - accuracy: 0.2000
# Epoch 16/100
# 5/5 [==============================] - 0s 1ms/step - loss: 9.0208e-04 - accuracy: 0.2000
# Epoch 17/100
# 5/5 [==============================] - 0s 1ms/step - loss: 8.7011e-04 - accuracy: 0.2000
# Epoch 18/100
# 5/5 [==============================] - 0s 1ms/step - loss: 8.3926e-04 - accuracy: 0.2000
# Epoch 19/100
# 5/5 [==============================] - 0s 5ms/step - loss: 8.0951e-04 - accuracy: 0.2000
# Epoch 20/100
# 5/5 [==============================] - 0s 6ms/step - loss: 7.8081e-04 - accuracy: 0.2000
# Epoch 21/100
# 5/5 [==============================] - 0s 1ms/step - loss: 7.5313e-04 - accuracy: 0.2000
# Epoch 22/100
# 5/5 [==============================] - 0s 1ms/step - loss: 7.2643e-04 - accuracy: 0.2000
# Epoch 23/100
# 5/5 [==============================] - 0s 1ms/step - loss: 7.0068e-04 - accuracy: 0.2000
# Epoch 24/100
# 5/5 [==============================] - 0s 1ms/step - loss: 6.7584e-04 - accuracy: 0.2000
# Epoch 25/100
# 5/5 [==============================] - 0s 1ms/step - loss: 6.5188e-04 - accuracy: 0.2000
# Epoch 26/100
# 5/5 [==============================] - 0s 2ms/step - loss: 6.2878e-04 - accuracy: 0.2000
# Epoch 27/100
# 5/5 [==============================] - 0s 2ms/step - loss: 6.0648e-04 - accuracy: 0.2000
# Epoch 28/100
# 5/5 [==============================] - 0s 1ms/step - loss: 5.8499e-04 - accuracy: 0.2000
# Epoch 29/100
# Epoch 87/100
# 5/5 [==============================] - 0s 1ms/step - loss: 6.9550e-05 - accuracy: 0.2000
# Epoch 88/100
# 5/5 [==============================] - 0s 2ms/step - loss: 6.7084e-05 - accuracy: 0.2000
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 6.4707e-05 - accuracy: 0.2000
# Epoch 90/100
# 5/5 [==============================] - 0s 1ms/step - loss: 6.2412e-05 - accuracy: 0.2000
# Epoch 91/100
# 5/5 [==============================] - 0s 6ms/step - loss: 6.0200e-05 - accuracy: 0.2000
# Epoch 92/100
# 5/5 [==============================] - 0s 7ms/step - loss: 5.8065e-05 - accuracy: 0.2000
# Epoch 93/100
# 5/5 [==============================] - 0s 2ms/step - loss: 5.6008e-05 - accuracy: 0.2000
# Epoch 94/100
# 5/5 [==============================] - 0s 1ms/step - loss: 5.4023e-05 - accuracy: 0.2000
# Epoch 95/100
# 5/5 [==============================] - 0s 1ms/step - loss: 5.2107e-05 - accuracy: 0.2000
# Epoch 96/100
# 5/5 [==============================] - 0s 2ms/step - loss: 5.0260e-05 - accuracy: 0.2000
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 4.8480e-05 - accuracy: 0.2000
# Epoch 98/100
# 5/5 [==============================] - 0s 2ms/step - loss: 4.6760e-05 - accuracy: 0.2000
# Epoch 99/100
# 5/5 [==============================] - 0s 1ms/step - loss: 4.5102e-05 - accuracy: 0.2000
# Epoch 100/100
# 5/5 [==============================] - 0s 2ms/step - loss: 4.3503e-05 - accuracy: 0.2000
# [[0.9889333]
#  [1.992349 ]
#  [2.9957647]
#  [3.9991803]
#  [5.002596 ]]

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

x = np.array([1,2,3])
y = np.array([1,2,3])
print(x.ndim)
print(x.shape)
print(x.shape[0]) # 배열의 원소를 세는법
print(len(x))  # 배열의 원소를 세는법

plt.plot(x,y, 'go' )
plt.plot(x,y, 'b-' )

plt.grid(True)
plt.show()
# Out:
# 1
# (3,)
# 3
# 3

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

x = np.array([1,2,3])
y = np.array([1,2,3])

w = 0.5
b = 1

y_hat = np.zeros(3)
print(y_hat)
print(len(x))
print(x.shape[0])

for i in range(len(x)):
    y_hat[i] = w*x[i] + b;
print(y_hat)

plt.plot(x,y, 'o' )
plt.plot(x,y, 'r-' )

plt.plot(x,y_hat, 'o' )
plt.plot(x,y_hat, 'b-' )

plt.grid(True)
plt.show()
# Out:
# [0. 0. 0.]
# 3
# 3
# [1.5 2.  2.5]

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

w = np.linspace(-1,3,100)
# print(w)
# print(len(w))
b = 0
x = 2
y = 2
j = np.zeros(100)
# print(j)
for i in range(len(w)):
    y_hat = w[i]*x + b;
    j[i] = 0.5 * (y_hat - y)**2

plt.plot(w,j, 'o' )
plt.plot(w,j, 'r-' )

plt.grid(True)
plt.show()

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

w = 1
b = np.linspace(-3,3,100)
x = 2
y = 2
j = np.zeros(100)
for i in range(len(b)):
    y_hat = w*x + b[i];
    j[i] = 0.5 * (y_hat - y)**2

plt.plot(b,j, 'o' )
plt.plot(b,j, 'r-' )

plt.grid(True)
plt.show()

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

# simple function to demo step size

b=0
x=2
y=2

def f(w) : # A parabola
    f = 0.5*((w*x+b)-y)**2
    return f
def Df(w) : # The derivative (gradient)
    Df = x*((w*x+b)-y)
    return Df
def xp1(w,alpha) : # update
    xp1 = w - alpha * Df(w)
    return xp1

def plot_steps( guess, alpha, nsteps) :
    fig, ax = plt.subplots()
    x = np.linspace(-1,3,100)
    ax.plot(x, f(x))
    x = guess
    ax.plot(x,f(x), 'o', label='start x=%.2f' %x )
    for i in range(nsteps):
        xold = x
        x = xp1(x,alpha)
        #ax.plot(x,f(x), 'o', label='x = %.2f' %x)
        ax.plot(x,f(x), 'o')
        ax.plot([xold,x],[f(xold),f(x)], '-')
    plt.legend()
    plt.show()
    
plot_steps(-0.5, 0.03, 50 )

# %%
import numpy as np   # numeriacal computing
import matplotlib.pyplot as plt  # plotting core

# simple function to demo step size

x=2
y=2
w=1

def f(b) : # A parabola
    f = 0.5*((w*x+b)-y)**2   
    return f
def Df(b) : # The derivative (gradient)
    Df = ((w*x+b)-y)*1
    return Df
def xp1(b,alpha) : # update
    xp1 = b - alpha * Df(b)
    return xp1

def plot_steps( guess, alpha, nsteps) :
    fig, ax = plt.subplots()
    x = np.linspace(-3,3,100)
    ax.plot(x, f(x))
    x = guess
    ax.plot(x,f(x), 'o', label='start x=%.2f' %x )
    for i in range(nsteps):
        xold = x
        x = xp1(x,alpha)
        #ax.plot(x,f(x), 'o', label='x = %.2f' %x)
        ax.plot(x,f(x), 'o')
        ax.plot([xold,x],[f(xold),f(x)], '-')
    plt.legend()
    plt.show()
    
plot_steps( 2, 0.09, 50 )

# %%
import matplotlib.pyplot as plt
import numpy as np

a0 = np.linspace(1,5,20)
# print(a0)
a1 = np.linspace(1,5,20)
# print(a1)
# plt.plot(a0, a1)
aa0, aa1 = np.meshgrid(a0, a1)
# print(aa0)
# print(aa1)
plt.plot(aa0, aa1 , 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# The function J
def J(a0, a1, x, y, m):
    ret=0
    for i in range(m):
        ret += 0.5*((a0 + a1*x[i]) - y[i] )**2
    return ret/m

x = np.linspace(-1,1,5)
y = x

#y = np.array([0.21378624, 1.97217916, 2.36737375, 5.13718724, 6.26470731])
a0 = np.linspace(-3,3,100)
a1 = np.linspace(-3,3,100)
aa0, aa1 = np.meshgrid(a0, a1)
plt.contour(aa0,aa1,J(aa0,aa1,x,y,m=len(x)) , colors='C0', levels=[i for i in np.arange(0,80,0.3)])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d.axes3d import Axes3D

fig = plt.figure()
ax = fig.add_subplot(1,1,1,projection='3d')

def pprint(arr):
    print("type:{}".format(type(arr)))
    print("shape: {}, dimension: {}, dtype:{}".format(arr.shape, arr.ndim, arr.dtype))
    print("Array's Data:\n", arr)

# The function J
def J(a0, a1, x, y, m):
    ret=0
    for i in range(m):
        ret += 0.5*((a0 + a1*x[i]) - y[i] )**2
    return ret/m

x = np.linspace(-1,1,5)
y = x
#y = np.array([0.21378624, 1.97217916, 2.36737375, 5.13718724, 6.26470731])
a0 = np.linspace(-3,3,100)
a1 = np.linspace(-3,3,100)

#pprint(x)
#pprint(y)
#pprint(a0)

#plt.plot(a1, J(a0,a1,x,y,m=len(x)) ) # set a0 to 0.1
aa0, aa1 = np.meshgrid(a0, a1)
ax.plot_surface(aa0, aa1, J(aa0,aa1,x,y,m=len(x)))

plt.show()

# %%
from sklearn.datasets import load_diabetes
diabetes = load_diabetes()
import matplotlib.pyplot as plt
# print(type(diabetes))
# print(diabetes)
print(diabetes.data.shape)  # (442,10)
print(diabetes.target.shape)
x = diabetes.data[:, 2]   # (442,)
print(x.shape)
y = diabetes.target

plt.scatter(x, y)
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# (442, 10)
# (442,)
# (442,)

# %%
w = 1.0
b = 1.0
rate = 0.01
for x_i, y_i in zip(x, y):  # epoch : 샘플 전체를 한번 순회하는 단위 => 1
    y_hat = x_i * w + b     # affine 연산
    err = y_hat - y_i
    w_rate = x_i
    w = w - rate * x_i * err
    b = b - rate * err

print('w=', w)
print('b=', b)
plt.scatter(x, y)
pt1 = (-0.1, -0.1 * w + b)
pt2 = (0.15, 0.15 * w + b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# w= 9.819118656206367
# b= 151.35590713560302

# %%
w = 1.0
b = 1.0
rate = 0.01
for i in range(1, 1000):  # epoch => 1000
    for x_i, y_i in zip(x, y):
        y_hat = x_i * w + b
        err = y_i - y_hat
        w_rate = x_i
        w = w + rate * x_i * err
        b = b + rate * err
print(w)
print(b)
plt.scatter(x, y)
pt1 = (-0.1, -0.1 * w + b)
pt2 = (0.15, 0.15 * w + b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]], 'r-')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
# Out:
# 942.7009346254105
# 151.7460812477738

# %% [markdown]
# #### 값 예측하기

# %%
x_new = 0.18
y_pred = x_new * w + b
print(y_pred)
# Out:
# 321.43224948034765

# %%
plt.scatter(x, y)
plt.scatter(x_new, y_pred)
plt.xlabel('x')
plt.ylabel('y')
plt.show()

# %% [markdown]
# #### 뉴런으로 만들기

# %%
class Neuron:
    
    def __init__(self):
        self.w = 1.0     # 가중치를 초기화합니다
        self.b = 1.0     # 절편을 초기화합니다
    
    def forpass(self, x):
        y_hat = x * self.w + self.b       # 직선 방정식을 계산합니다
        return y_hat
    
    def backprop(self, x, err):
        w_grad = x * err    # 가중치에 대한 그래디언트를 계산합니다
        b_grad = 1 * err    # 절편에 대한 그래디언트를 계산합니다
        return w_grad, b_grad

    def fit(self, x, y, epochs=100, rate=0.01):
        for i in range(epochs):           # 에포크만큼 반복합니다
            for x_i, y_i in zip(x, y):    # 모든 샘플에 대해 반복합니다
                y_hat = self.forpass(x_i) # 정방향 계산
                err = y_hat - y_i      # 오차 계산
                w_grad, b_grad = self.backprop(x_i, err)  # 역방향 계산
                self.w -= rate*w_grad          # 가중치 업데이트
                self.b -= rate*b_grad          # 절편 업데이트
                
neuron = Neuron()
neuron.fit(x, y, 1000)

plt.scatter(x, y)
pt1 = (-0.1, -0.1 * neuron.w + neuron.b)
pt2 = (0.15, 0.15 * neuron.w + neuron.b)
plt.plot([pt1[0], pt2[0]], [pt1[1], pt2[1]],'r')
plt.xlabel('x')
plt.ylabel('y')
plt.show()
